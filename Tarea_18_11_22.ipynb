# %% [markdown]
# <a href="https://colab.research.google.com/github/jmcajigas/PDI/blob/main/Tarea_18_11_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Implementación segunda derivada
# Juan Manuel Cajigas Eraso \\
# C.C:1193458123 \\
# jcajigas@unal.edu.co

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
x = tf.linspace(-10, 10, 201)

# %%
with tf.GradientTape() as tape:
  tape.watch(x)
  with tf.GradientTape() as tape2:
    tape2.watch(x)
    y=tf.sin(x)
  dy_dx= tape2.gradient(y,x)
d2y_d2x= tape.gradient(dy_dx,x)

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y, label='y')
plt.plot(x,dy_dx, label='dy/dx')
plt.plot(x,d2y_d2x, label='d2y/d2x')
plt.legend()
